# %% [markdown]
# <a href="https://colab.research.google.com/github/Tenuka-R/FlyRank-starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tenuka-R/FlyRank-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My chosen lane is: Refresh/content opportunity scoring
# The reason is that it helps a reviewer to identify which pages to first review and have the highest likelihood of doing well after a rewrite/refresh

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision that my work would improve is which pages should a reviewer look at first out of a huge list of pages.
#
# A content reviewer would act on it to refresh and rewrite the page once identified as appropriate to do so.
#
# The cost of a wrong recommendation would be that the content reviewer spends their valuable time rewriting a page that was not going to perform well after the refresh and may continue to decline

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Total rows: {len(df):,}")
print(f"Total columns: {df.shape[1]}")
print(f"Unique clients: {df['client_id'].nunique()}")

filtered = df[(df["impressions_90d"] > 0) & (df["content_age_days"] >= 90)]
print(f"\nRows after impressions_90d > 0 and content_age_days >= 90: {len(filtered):,}")

no_position_data = (filtered["avg_position"] == 0).sum()
print(f"Rows with avg_position equal to 0: {no_position_data:,}")
# Out:
# Total rows: 30,000
# Total columns: 44
# Unique clients: 32
#
# Rows after impressions_90d > 0 and content_age_days >= 90: 30,000
# Rows with avg_position equal to 0: 1,205

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# My work will be able to say:
# - Which pages show signs of declining
# - List of pages worth reviewing and refreshing
# - Statements such as "this page's visibility has dropped over a certain period of time
#
# My work will not be able to say:
# - Refreshing a page will cause it to perform better
# - A drop in impressions automatically means a decline
# - The score is a guarantee and perfect

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
